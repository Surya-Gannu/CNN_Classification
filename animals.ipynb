# %%
import numpy as np
import random 
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
# Out:
# c:\Users\surya\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\export\tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):

# %%
X_train=np.loadtxt('input.csv',delimiter=',')
Y_train=np.loadtxt('labels.csv',delimiter=',')

X_test=np.loadtxt('input_test.csv',delimiter=',')
Y_test=np.loadtxt('labels_test.csv',delimiter=',')

# %%
X_train = X_train.reshape(len(X_train),100,100,3)
Y_train = Y_train.reshape(len(Y_train),1)

X_test = X_test.reshape(len(X_test),100,100,3)
Y_test = Y_test.reshape(len(Y_test),1)

X_train = X_train / 255.0
X_test = X_test / 255.0

#data augmentation to improve training
datagen = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    zoom_range=0.2
)

# %%
print("shape of X_train:", X_train.shape)
print("shape of Y_train:", Y_train.shape)
print("shape of X_test:", X_test.shape) 
print("shape of Y_test:", Y_test.shape)
# Out:
# shape of X_train: (2000, 100, 100, 3)
# shape of Y_train: (2000, 1)
# shape of X_test: (400, 100, 100, 3)
# shape of Y_test: (400, 1)

# %%
idx = random.randint(0, len(X_train))
plt.imshow(X_train[idx, :])
plt.show()

# %%
model=Sequential([
    Conv2D(32,(3,3),activation='relu',input_shape=(100,100,3)),
    MaxPooling2D((2,2)),

    Conv2D(32,(3,3),activation='relu'),
    MaxPooling2D((2,2)),
    
    Flatten(),
    Dense(64,activation='relu'),
    Dense(1,activation='sigmoid')
])
# Out:
# c:\Users\surya\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model = Sequential()

model.add(Conv2D(32, (3,3), activation= 'relu', input_shape = (100,100,3))) # 32,64 is the filter
model.add(MaxPooling2D((2,2)))# converting 2d data to 1d data
model.add(Dropout(0.25)) # to remove particular data from the dataset

model.add(Conv2D(64, (3,3), activation= 'relu'))#(3,3) is the size of the filter( hidden layers)
model.add(MaxPooling2D((2,2)))
model.add(Dropout(0.25))

model.add(Conv2D(128,(3,3), activation='relu'))
model.add(MaxPooling2D(2,2))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(128, activation = 'relu'))
model.add(Dropout(0.5))
model.add(Dense(1, activation = 'sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.fit(datagen.flow(X_train, Y_train, batch_size=32),
          epochs=30,
          validation_data=(X_test, Y_test),
          verbose=1)
# Out:
# Epoch 1/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 12s 159ms/step - accuracy: 0.5040 - loss: 0.7194 - val_accuracy: 0.5025 - val_loss: 0.6931
# Epoch 2/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 149ms/step - accuracy: 0.4935 - loss: 0.6935 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 3/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 152ms/step - accuracy: 0.4970 - loss: 0.6932 - val_accuracy: 0.5150 - val_loss: 0.6928
# Epoch 4/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 9s 148ms/step - accuracy: 0.5220 - loss: 0.6924 - val_accuracy: 0.5200 - val_loss: 0.6796
# Epoch 5/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 57s 910ms/step - accuracy: 0.5410 - loss: 0.6873 - val_accuracy: 0.6075 - val_loss: 0.6680
# Epoch 6/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 48s 753ms/step - accuracy: 0.5540 - loss: 0.6758 - val_accuracy: 0.5975 - val_loss: 0.6559
# Epoch 7/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 44s 695ms/step - accuracy: 0.5555 - loss: 0.6853 - val_accuracy: 0.6200 - val_loss: 0.6768
# Epoch 8/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 43s 688ms/step - accuracy: 0.5720 - loss: 0.6801 - val_accuracy: 0.5900 - val_loss: 0.6756
# Epoch 9/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 43s 680ms/step - accuracy: 0.5755 - loss: 0.6741 - val_accuracy: 0.5675 - val_loss: 0.6715
# Epoch 10/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 41s 637ms/step - accuracy: 0.5740 - loss: 0.6717 - val_accuracy: 0.6325 - val_loss: 0.6512
# Epoch 11/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 43s 683ms/step - accuracy: 0.5775 - loss: 0.6738 - val_accuracy: 0.6150 - val_loss: 0.6707
# Epoch 12/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 42s 671ms/step - accuracy: 0.5785 - loss: 0.6758 - val_accuracy: 0.5375 - val_loss: 0.6784
# Epoch 13/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 80s 629ms/step - accuracy: 0.5560 - loss: 0.6784 - val_accuracy: 0.6225 - val_loss: 0.6583
# Epoch 14/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 39s 613ms/step - accuracy: 0.5670 - loss: 0.6798 - val_accuracy: 0.6125 - val_loss: 0.6680
# Epoch 15/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 38s 593ms/step - accuracy: 0.5890 - loss: 0.6711 - val_accuracy: 0.6300 - val_loss: 0.6526
# Epoch 16/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 38s 609ms/step - accuracy: 0.5875 - loss: 0.6735 - val_accuracy: 0.6050 - val_loss: 0.6571
# Epoch 17/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 39s 615ms/step - accuracy: 0.5840 - loss: 0.6742 - val_accuracy: 0.6175 - val_loss: 0.6444
# Epoch 18/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 36s 572ms/step - accuracy: 0.6140 - loss: 0.6610 - val_accuracy: 0.6025 - val_loss: 0.6675
# Epoch 19/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 38s 602ms/step - accuracy: 0.6030 - loss: 0.6578 - val_accuracy: 0.6550 - val_loss: 0.6345
# Epoch 20/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 42s 613ms/step - accuracy: 0.6260 - loss: 0.6559 - val_accuracy: 0.6625 - val_loss: 0.6295
# Epoch 21/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 38s 601ms/step - accuracy: 0.6145 - loss: 0.6461 - val_accuracy: 0.6375 - val_loss: 0.6271
# Epoch 22/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 39s 619ms/step - accuracy: 0.6165 - loss: 0.6581 - val_accuracy: 0.6575 - val_loss: 0.6052
# Epoch 23/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 37s 589ms/step - accuracy: 0.6095 - loss: 0.6511 - val_accuracy: 0.6675 - val_loss: 0.6333
# Epoch 24/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 38s 597ms/step - accuracy: 0.6260 - loss: 0.6358 - val_accuracy: 0.6750 - val_loss: 0.5935
# Epoch 25/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 44s 693ms/step - accuracy: 0.6460 - loss: 0.6308 - val_accuracy: 0.6900 - val_loss: 0.5824
# Epoch 26/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 76s 603ms/step - accuracy: 0.6385 - loss: 0.6338 - val_accuracy: 0.6825 - val_loss: 0.5825
# Epoch 27/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 37s 581ms/step - accuracy: 0.6380 - loss: 0.6247 - val_accuracy: 0.7175 - val_loss: 0.5878
# Epoch 28/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 43s 681ms/step - accuracy: 0.6500 - loss: 0.6266 - val_accuracy: 0.7225 - val_loss: 0.5775
# Epoch 29/30
# 27/63 ━━━━━━━━━━━━━━━━━━━━ 23s 656ms/step - accuracy: 0.6341 - loss: 0.6300

# %%
model.evaluate(X_test, Y_test)
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.7525 - loss: 0.5024
# [0.5024316906929016, 0.7524999976158142]

# %%
idx2= random.randint(0, len(Y_test))
plt.imshow(X_test[idx2, :])
plt.show()

y_pred = model.predict(X_test[idx2, :].reshape(1,100,100,3))
y_pred = y_pred > 0.5

if(y_pred == 0):
    pred = "dog"

else: 
    pred = 'cat'

print("The model prediction is", pred)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# The model prediction is cat

# %%
model.save('model.h5')
print('our model is saved')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# our model is saved
